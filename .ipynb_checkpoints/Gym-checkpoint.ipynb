# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib nbagg
# import networkx as nx
import numpy as np
import cvxpy as cvx
from pprint import pprint
from random import shuffle
import time
from contagion import binarize_probabilities, distribute_liabilities, make_connections, DeterministicRatioNetwork

# %%
defaults_to_freq = {}

for _ in range(10000):
    cash_vector = np.random.normal(10000, 10000, 100)
    cash_vector[cash_vector <= 0] = 1*10**-10
    # cash_vector[cash_vector > 5000] = 6500
    cash_to_connectivity = lambda x: np.log(x).astype(int)
    connectivity_vector = cash_to_connectivity(cash_vector)
    
    # Make the adjacency matrix
    mat = make_connections(connectivity_vector)
    mat = binarize_probabilities(mat)

    # Distribute liabilities
    leverage_ratios = np.random.normal(10, 2, 100)
    leverage_ratios[leverage_ratios < 5] = 5

    liabilities = np.multiply(cash_vector, leverage_ratios)
    mat = distribute_liabilities(mat, liabilities)
    for i, cash in enumerate(cash_vector):
        mat[i, i] = cash
    model = DeterministicRatioNetwork(100, mat)
    model.reset_net()

    ratios, defaults = model.step()
    if defaults in defaults_to_freq:
        defaults_to_freq[defaults] += 1
    else:
        defaults_to_freq[defaults] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2d4da6196e5c> in <module>()
#       9
#      10     # Make the adjacency matrix
# ---> 11     mat = make_connections(connectivity_vector)
#      12     mat = binarize_probabilities(mat)
#      13
#
# /Users/ethanpetersen/Desktop/GitHub/Avalanche/contagion.py in make_connections(connectivity_vector, randomize, probabilities)
#      46
#      47     problem = cvx.Problem(objective, constraints)
# ---> 48     problem.solve()
#      49
#      50     real_connections = connections.value
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/problems/problem.pyc in solve(self, *args, **kwargs)
#     207             return func(self, *args, **kwargs)
#     208         else:
# --> 209             return self._solve(*args, **kwargs)
#     210
#     211     @classmethod
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/problems/problem.pyc in _solve(self, solver, ignore_dcp, warm_start, verbose, parallel, **kwargs)
#     298
#     299         # Standard cone problem
# --> 300         objective, constraints = self.canonicalize()
#     301
#     302         # Solve in parallel
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/problems/problem.pyc in canonicalize(self)
#     134
#     135         for constr in self.constraints:
# --> 136             canon_constr += constr.canonical_form[1]
#     137
#     138         return (obj, canon_constr)
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/utilities/performance_utils.pyc in _lazyprop(self)
#      35         """
#      36         if not hasattr(self, attr_name):
# ---> 37             setattr(self, attr_name, func(self))
#      38         return getattr(self, attr_name)
#      39     return _lazyprop
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/utilities/canonical.pyc in canonical_form(self)
#      42             A tuple of (affine expression, [constraints]).
#      43         """
# ---> 44         return self.canonicalize()
#      45
#      46     @abc.abstractmethod
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/constraints/leq_constraint.pyc in canonicalize(self)
#     103             A tuple of (affine expression, [constraints]).
#     104         """
# --> 105         obj, constraints = self._expr.canonical_form
#     106         dual_holder = lu.create_leq(obj, constr_id=self.id)
#     107         return (None, constraints + [dual_holder])
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/utilities/performance_utils.pyc in _lazyprop(self)
#      35         """
#      36         if not hasattr(self, attr_name):
# ---> 37             setattr(self, attr_name, func(self))
#      38         return getattr(self, attr_name)
#      39     return _lazyprop
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/utilities/canonical.pyc in canonical_form(self)
#      42             A tuple of (affine expression, [constraints]).
#      43         """
# ---> 44         return self.canonicalize()
#      45
#      46     @abc.abstractmethod
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/atoms/atom.pyc in canonicalize(self)
#     147         """
#     148         # Constant atoms are treated as a leaf.
# --> 149         if self.is_constant():
#     150             # Parameterized expressions are evaluated later.
#     151             if self.parameters():
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/expressions/expression.pyc in is_constant(self)
#     120         """Is the expression constant?
#     121         """
# --> 122         return len(self.variables()) == 0 or self.is_zero()
#     123
#     124     def is_affine(self):
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/expressions/expression.pyc in is_zero(self)
#     175         """Is the expression all zero?
#     176         """
# --> 177         return self.is_positive() and self.is_negative()
#     178
#     179     @abc.abstractmethod
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/atoms/atom.pyc in is_positive(self)
#      72         """Is the expression positive?
#      73         """
# ---> 74         return self.sign_from_args()[0]
#      75
#      76     @clru_cache(maxsize=100)
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/atoms/affine/affine_atom.pyc in sign_from_args(self)
#      31         """By default, the sign is the most general of all the argument signs.
#      32         """
# ---> 33         return u.sign.sum_signs([arg for arg in self.args])
#      34
#      35     def is_atom_convex(self):
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/utilities/sign.pyc in sum_signs(exprs)
#      25         The sign (is pos, is neg) of the sum.
#      26     """
# ---> 27     is_pos = all([expr.is_positive() for expr in exprs])
#      28     is_neg = all([expr.is_negative() for expr in exprs])
#      29     return (is_pos, is_neg)
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/atoms/atom.pyc in is_positive(self)
#      72         """Is the expression positive?
#      73         """
# ---> 74         return self.sign_from_args()[0]
#      75
#      76     @clru_cache(maxsize=100)
#
# /Users/ethanpetersen/anaconda/lib/python2.7/site-packages/cvxpy/atoms/affine/unary_operators.pyc in sign_from_args(self)
#      48         """Returns sign (is positive, is negative) of the expression.
#      49         """
# ---> 50         return (self.args[0].is_negative(), self.args[0].is_positive())
#      51
#      52     def is_incr(self, idx):
#
# KeyboardInterrupt:

# %%
defaults_to_freq

# %%
model = DeterministicRatioNetwork(100, mat)
f, ax = plt.subplots()
def data_gen():
    while True:
        yield mat
def animate(i):
    model.step()
    data = model.liabilities
    plt.pcolor(np.array(data))
ani = animation.FuncAnimation(f, animate, data_gen, interval=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
line, = ax.plot(np.random.rand(100))
# ax.set_ylim(0, 1)

model = DeterministicRatioNetwork(100, mat)
defaults_to_freq = {}


def update(data):
    ratios = data[0]
    defaults = data[1]
    if defaults in defaults_to_freq:
        defaults_to_freq[defaults] += 1
    else:
        defaults_to_freq[defaults] = 1
    line.set_ydata(ratios)
    return line,


def data_gen():
    for i in xrange(1000):
        yield model.step()

ani = animation.FuncAnimation(fig, update, data_gen, interval=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
